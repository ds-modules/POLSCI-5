# %%
import pandas as pd
import numpy as np

# %%
wars = pd.read_csv('ucdp-term-dyadic-2015.csv') # load in data
wars
# Out:
#      ConflictId  DyadId   DyadEp  Year                  Location  \
# 0         1-191       1      101  1992                   Algeria
# 1         1-191       1      101  1993                   Algeria
# 2         1-191       1      101  1994                   Algeria
# 3         1-191       1      101  1995                   Algeria
# 4         1-191       1      101  1996                   Algeria
# 5         1-191       1      101  1997                   Algeria
# 6         1-191       2      201  1991                   Algeria
# 7         1-191       3      301  1993                   Algeria
# 8         1-191       3      301  1994                   Algeria
# 9         1-191       3      301  1995                   Algeria
# 10        1-191       3      301  1996                   Algeria
# 11        1-191       3      301  1997                   Algeria
# 12        1-191       3      301  1998                   Algeria
# 13        1-191       3      301  1999                   Algeria
# 14        1-191       3      301  2000                   Algeria
# 15        1-191       3      301  2001                   Algeria
# 16        1-191       3      301  2002                   Algeria
# 17        1-191       3      301  2003                   Algeria
# 18        1-191       4      401  1999                   Algeria
# 19        1-191       4      401  2000                   Algeria
# 20        1-191       4      401  2001                   Algeria
# 21        1-191       4      401  2002                   Algeria
# 22        1-191       4      401  2003                   Algeria
# 23        1-191       4      401  2004                   Algeria
# 24        1-191       4      401  2005                   Algeria
# 25        1-191       4      401  2006                   Algeria
# 26        1-191       4      401  2007                   Algeria
# 27        1-191       4      401  2008                   Algeria
# 28        1-191       4      401  2009                   Algeria
# 29        1-191       4      401  2010                   Algeria
# ...         ...     ...      ...   ...                       ...
# 2711      1-274     863    86302  2013                      Mali
# 2712      1-274     863    86302  2014                      Mali
# 2713      1-274     865    86501  2013                      Mali
# 2714      1-102     867    86701  2011                     Syria
# 2715      1-102     867    86701  2012                     Syria
# 2716      1-102     867    86701  2013                     Syria
# 2717      1-102     867    86701  2014                     Syria
# 2718       1-33   10855  1085501  2014       Yemen (North Yemen)
# 2719      1-209   10961  1096101  2014                  Pakistan
# 2720      1-139   11299  1129901  2004                     India
# 2721       1-86   11377  1137701  2014          DR Congo (Zaire)
# 2722       1-29   11932  1193201  2000                     India
# 2723      1-222   12380  1238001  2013  Central African Republic
# 2724       1-86   12463  1246301  2013          DR Congo (Zaire)
# 2725      1-196   12487  1248701  2014                     Egypt
# 2726      1-274   12582  1258201  2014                      Mali
# 2727      1-271   14059  1405901  2014                     Libya
# 2728      1-280   14085  1408501  2014                   Ukraine
# 2729      1-227   14102  1410201  2013                     India
# 2730      1-227   14102  1410201  2014                     India
# 2731      1-281   14124  1412401  2014                   Ukraine
# 2732      1-113   14134  1413401  2014                     Sudan
# 2733      1-113   14150  1415001  2014                     Sudan
# 2734      1-282   14184  1418401  2014                   Ukraine
# 2735      1-283   14210  1421001  2014                   Ukraine
# 2736      1-209   14227  1422701  2014                  Pakistan
# 2737       1-63   14244  1424401  2014                   Lebanon
# 2738      1-271   14249  1424901  2014                     Libya
# 2739      1-279   14273  1427301  2013           Myanmar (Burma)
# 2740      1-279   14273  1427301  2014           Myanmar (Burma)
#
#                                        SideA  \
# 0                      Government of Algeria
# 1                      Government of Algeria
# 2                      Government of Algeria
# 3                      Government of Algeria
# 4                      Government of Algeria
# 5                      Government of Algeria
# 6                      Government of Algeria
# 7                      Government of Algeria
# 8                      Government of Algeria
# 9                      Government of Algeria
# 10                     Government of Algeria
# 11                     Government of Algeria
# 12                     Government of Algeria
# 13                     Government of Algeria
# 14                     Government of Algeria
# 15                     Government of Algeria
# 16                     Government of Algeria
# 17                     Government of Algeria
# 18                     Government of Algeria
# 19                     Government of Algeria
# 20                     Government of Algeria
# 21                     Government of Algeria
# 22                     Government of Algeria
# 23                     Government of Algeria
# 24                     Government of Algeria
# 25                     Government of Algeria
# 26                     Government of Algeria
# 27                     Government of Algeria
# 28                     Government of Algeria
# 29                     Government of Algeria
# ...                                      ...
# 2711                      Government of Mali
# 2712                      Government of Mali
# 2713                      Government of Mali
# 2714                     Government of Syria
# 2715                     Government of Syria
# 2716                     Government of Syria
# 2717                     Government of Syria
# 2718       Government of Yemen (North Yemen)
# 2719                  Government of Pakistan
# 2720                     Government of India
# 2721         Government of DR Congo (Zaire)
# 2722                     Government of India
# 2723  Government of Central African Republic
# 2724         Government of DR Congo (Zaire)
# 2725                     Government of Egypt
# 2726                      Government of Mali
# 2727                     Government of Libya
# 2728                   Government of Ukraine
# 2729                     Government of India
# 2730                     Government of India
# 2731                   Government of Ukraine
# 2732                     Government of Sudan
# 2733                     Government of Sudan
# 2734                   Government of Ukraine
# 2735                   Government of Ukraine
# 2736                  Government of Pakistan
# 2737                   Government of Lebanon
# 2738                     Government of Libya
# 2739           Government of Myanmar (Burma)
# 2740           Government of Myanmar (Burma)
#
#                                                SideA2nd  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23    Government of Chad, Government of Mali, Govern...
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2711  Government of Bangladesh, Government of Belgiu...
# 2712  Government of Bangladesh, Government of Belgiu...
# 2713  Government of Bangladesh, Government of Belgiu...
# 2714                                                NaN
# 2715                                                NaN
# 2716                                                NaN
# 2717                                                NaN
# 2718                                                NaN
# 2719                                                NaN
# 2720                                                NaN
# 2721                                                NaN
# 2722                                                NaN
# 2723                                                NaN
# 2724                                                NaN
# 2725                                                NaN
# 2726  Government of Bangladesh, Government of Belgiu...
# 2727                                                NaN
# 2728                                                NaN
# 2729                                                NaN
# 2730                                                NaN
# 2731                                                NaN
# 2732                                                NaN
# 2733                                                NaN
# 2734                                                NaN
# 2735                                                NaN
# 2736                                                NaN
# 2737                                                NaN
# 2738                                                NaN
# 2739                                                NaN
# 2740                                                NaN
#
#                                    SideB SideBID  \
# 0                                    AIS    1389
# 1                                    AIS    1389
# 2                                    AIS    1389
# 3                                    AIS    1389
# 4                                    AIS    1389
# 5                                    AIS    1389
# 6                      Takfir wa'l Hijra    1388
# 7                                    GIA    1390
# 8                                    GIA    1390
# 9                                    GIA    1390
# 10                                   GIA    1390
# 11                                   GIA    1390
# 12                                   GIA    1390
# 13                                   GIA    1390
# 14                                   GIA    1390
# 15                                   GIA    1390
# 16                                   GIA    1390
# 17                                   GIA    1390
# 18                                  AQIM    1391
# 19                                  AQIM    1391
# 20                                  AQIM    1391
# 21                                  AQIM    1391
# 22                                  AQIM    1391
# 23                                  AQIM    1391
# 24                                  AQIM    1391
# 25                                  AQIM    1391
# 26                                  AQIM    1391
# 27                                  AQIM    1391
# 28                                  AQIM    1391
# 29                                  AQIM    1391
# ...                                  ...     ...
# 2711                                AQIM    1391
# 2712                                AQIM    1391
# 2713           Signed-in-Blood Battalion    2120
# 2714                   Syrian insurgents    4456
# 2715                   Syrian insurgents    4456
# 2716                   Syrian insurgents    4456
# 2717                   Syrian insurgents    4456
# 2718                          Ansarallah    1976
# 2719                                 IMU    1202
# 2720                              NLFT-B    2939
# 2721                           PARC-FAAL    3043
# 2722                            CPI-ML-J    3946
# 2723                         anti-Balaka    4201
# 2724   Forces of Paul Joseph Mukungubila    4286
# 2725                               IS-SP    4319
# 2726                        al-Murabitun    4376
# 2727                Libyan National Army    5802
# 2728                              Maidan    5817
# 2729                              NDFB-S    5826
# 2730                              NDFB-S    5826
# 2731           Donetsk People's Republic    5840
# 2732                                SARC    5849
# 2733      Darfur Joint Resistance Forces    5866
# 2734           Lugansk People's Republic    5839
# 2735  United Armed Forces of Novorossiya    5914
# 2736                     Jamaat-ul-Ahrar    5928
# 2737                                  IS    1076
# 2738                     Zintan Brigades    5940
# 2739                                PSLF    5965
# 2740                                PSLF    5965
#
#                                  SideB2nd    ...     Outcome CfireDate  \
# 0                                     NaN    ...         NaN       NaN
# 1                                     NaN    ...         NaN       NaN
# 2                                     NaN    ...         NaN       NaN
# 3                                     NaN    ...         NaN       NaN
# 4                                     NaN    ...         NaN       NaN
# 5                                     NaN    ...           2   10/1/97
# 6                                     NaN    ...           6       NaN
# 7                                     NaN    ...         NaN       NaN
# 8                                     NaN    ...         NaN       NaN
# 9                                     NaN    ...         NaN       NaN
# 10                                    NaN    ...         NaN       NaN
# 11                                    NaN    ...         NaN       NaN
# 12                                    NaN    ...         NaN       NaN
# 13                                    NaN    ...         NaN       NaN
# 14                                    NaN    ...         NaN       NaN
# 15                                    NaN    ...         NaN       NaN
# 16                                    NaN    ...         NaN       NaN
# 17                                    NaN    ...           5       NaN
# 18                                    NaN    ...         NaN       NaN
# 19                                    NaN    ...         NaN       NaN
# 20                                    NaN    ...         NaN       NaN
# 21                                    NaN    ...         NaN       NaN
# 22                                    NaN    ...         NaN       NaN
# 23                                    NaN    ...         NaN       NaN
# 24                                    NaN    ...         NaN       NaN
# 25                                    NaN    ...         NaN       NaN
# 26                                    NaN    ...         NaN       NaN
# 27                                    NaN    ...         NaN       NaN
# 28                                    NaN    ...         NaN       NaN
# 29                                    NaN    ...         NaN       NaN
# ...                                   ...    ...         ...       ...
# 2711                                  NaN    ...         NaN       NaN
# 2712                                  NaN    ...           .         .
# 2713                                  NaN    ...         NaN       NaN
# 2714                                  NaN    ...         NaN       NaN
# 2715                                  NaN    ...         NaN       NaN
# 2716                                  NaN    ...         NaN       NaN
# 2717                                  NaN    ...           .         .
# 2718                                  NaN    ...           .         .
# 2719                                  NaN    ...           .         .
# 2720                                  NaN    ...           5       NaN
# 2721                                  NaN    ...           .         .
# 2722                                  NaN    ...           5       NaN
# 2723                                  NaN    ...           5       NaN
# 2724                                  NaN    ...           3       NaN
# 2725                                  NaN    ...           .         .
# 2726                                  NaN    ...           .         .
# 2727                                  NaN    ...           .         .
# 2728                                  NaN    ...           .         .
# 2729                                  NaN    ...         NaN       NaN
# 2730                                  NaN    ...           .         .
# 2731  Government of Russia (Soviet Union)    ...           .         .
# 2732                                  NaN    ...           .         .
# 2733                                  NaN    ...           .         .
# 2734  Government of Russia (Soviet Union)    ...           .         .
# 2735  Government of Russia (Soviet Union)    ...           .         .
# 2736                                  NaN    ...           .         .
# 2737                                  NaN    ...           .         .
# 2738                                  NaN    ...           .         .
# 2739                                  NaN    ...         NaN       NaN
# 2740                                  NaN    ...           .         .
#
#       PeAgDate  GWNoA                                           GWNoA2nd  \
# 0          NaN    615                                                NaN
# 1          NaN    615                                                NaN
# 2          NaN    615                                                NaN
# 3          NaN    615                                                NaN
# 4          NaN    615                                                NaN
# 5          NaN    615                                                NaN
# 6          NaN    615                                                NaN
# 7          NaN    615                                                NaN
# 8          NaN    615                                                NaN
# 9          NaN    615                                                NaN
# 10         NaN    615                                                NaN
# 11         NaN    615                                                NaN
# 12         NaN    615                                                NaN
# 13         NaN    615                                                NaN
# 14         NaN    615                                                NaN
# 15         NaN    615                                                NaN
# 16         NaN    615                                                NaN
# 17         NaN    615                                                NaN
# 18         NaN    615                                                NaN
# 19         NaN    615                                                NaN
# 20         NaN    615                                                NaN
# 21         NaN    615                                                NaN
# 22         NaN    615                                                NaN
# 23         NaN    615                                      483, 432, 436
# 24         NaN    615                                                NaN
# 25         NaN    615                                                NaN
# 26         NaN    615                                                NaN
# 27         NaN    615                                                NaN
# 28         NaN    615                                                NaN
# 29         NaN    615                                                NaN
# ...        ...    ...                                                ...
# 2711       NaN    432  771, 211, 434, 439, 516, 811, 483, 710, 651, 3...
# 2712         .    432  771, 211, 434, 439, 516, 811, 483, 710, 651, 3...
# 2713       NaN    432  771, 211, 434, 439, 516, 811, 483, 710, 651, 3...
# 2714       NaN    652                                                NaN
# 2715       NaN    652                                                NaN
# 2716       NaN    652                                                NaN
# 2717         .    652                                                NaN
# 2718         .    678                                                NaN
# 2719         .    770                                                NaN
# 2720       NaN    750                                                NaN
# 2721         .    490                                                NaN
# 2722       NaN    750                                                NaN
# 2723       NaN    482                                                NaN
# 2724       NaN    490                                                NaN
# 2725         .    651                                                NaN
# 2726         .    432  771, 211, 434, 439, 516, 811, 483, 710, 651, 3...
# 2727         .    620                                                NaN
# 2728         .    369                                                NaN
# 2729       NaN    750                                                NaN
# 2730         .    750                                                NaN
# 2731         .    369                                                NaN
# 2732         .    625                                                NaN
# 2733         .    625                                                NaN
# 2734         .    369                                                NaN
# 2735         .    369                                                NaN
# 2736         .    770                                                NaN
# 2737         .    660                                                NaN
# 2738         .    620                                                NaN
# 2739       NaN    775                                                NaN
# 2740         .    775                                                NaN
#
#      GWNoB  GWNoB2nd GWNoLoc  Region   Version
# 0      NaN       NaN     615       4  2.0-2015
# 1      NaN       NaN     615       4  2.0-2015
# 2      NaN       NaN     615       4  2.0-2015
# 3      NaN       NaN     615       4  2.0-2015
# 4      NaN       NaN     615       4  2.0-2015
# 5      NaN       NaN     615       4  2.0-2015
# 6      NaN       NaN     615       4  2.0-2015
# 7      NaN       NaN     615       4  2.0-2015
# 8      NaN       NaN     615       4  2.0-2015
# 9      NaN       NaN     615       4  2.0-2015
# 10     NaN       NaN     615       4  2.0-2015
# 11     NaN       NaN     615       4  2.0-2015
# 12     NaN       NaN     615       4  2.0-2015
# 13     NaN       NaN     615       4  2.0-2015
# 14     NaN       NaN     615       4  2.0-2015
# 15     NaN       NaN     615       4  2.0-2015
# 16     NaN       NaN     615       4  2.0-2015
# 17     NaN       NaN     615       4  2.0-2015
# 18     NaN       NaN     615       4  2.0-2015
# 19     NaN       NaN     615       4  2.0-2015
# 20     NaN       NaN     615       4  2.0-2015
# 21     NaN       NaN     615       4  2.0-2015
# 22     NaN       NaN     615       4  2.0-2015
# 23     NaN       NaN     615       4  2.0-2015
# 24     NaN       NaN     615       4  2.0-2015
# 25     NaN       NaN     615       4  2.0-2015
# 26     NaN       NaN     615       4  2.0-2015
# 27     NaN       NaN     615       4  2.0-2015
# 28     NaN       NaN     615       4  2.0-2015
# 29     NaN       NaN     615       4  2.0-2015
# ...    ...       ...     ...     ...       ...
# 2711   NaN       NaN     432       4  2.0-2015
# 2712   NaN       NaN     432       4  2.0-2015
# 2713   NaN       NaN     432       4  2.0-2015
# 2714   NaN       NaN     652       2  2.0-2015
# 2715   NaN       NaN     652       2  2.0-2015
# 2716   NaN       NaN     652       2  2.0-2015
# 2717   NaN       NaN     652       2  2.0-2015
# 2718   NaN       NaN     678       2  2.0-2015
# 2719   NaN       NaN     770       3  2.0-2015
# 2720   NaN       NaN     750       3  2.0-2015
# 2721   NaN       NaN     490       4  2.0-2015
# 2722   NaN       NaN     750       3  2.0-2015
# 2723   NaN       NaN     482       4  2.0-2015
# 2724   NaN       NaN     490       4  2.0-2015
# 2725   NaN       NaN     651       2  2.0-2015
# 2726   NaN       NaN     432       4  2.0-2015
# 2727   NaN       NaN     620       4  2.0-2015
# 2728   NaN       NaN     369       1  2.0-2015
# 2729   NaN       NaN     750       3  2.0-2015
# 2730   NaN       NaN     750       3  2.0-2015
# 2731   NaN       365     369       1  2.0-2015
# 2732   NaN       NaN     625       4  2.0-2015
# 2733   NaN       NaN     625       4  2.0-2015
# 2734   NaN       365     369       1  2.0-2015
# 2735   NaN       365     369       1  2.0-2015
# 2736   NaN       NaN     770       3  2.0-2015
# 2737   NaN       NaN     660       2  2.0-2015
# 2738   NaN       NaN     620       4  2.0-2015
# 2739   NaN       NaN     775       3  2.0-2015
# 2740   NaN       NaN     775       3  2.0-2015
#
# [2741 rows x 33 columns]

# %%
# drop unused columns
dropped = wars.drop(['DyadEp', 'SideBID', 'StartPrec', 'StartDate2', 'StartPrec2', 'Dyadterm', 
           'EpEndPrec', 'Outcome_early', 'GWNoA', 'GWNoA2nd', 'GWNoB', 'GWNoB2nd', 'GWNoLoc', 'Version', 'Type2'], axis=1)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd  Incompatibility TerritoryName  IntensityLevel  TypeOfConflict  \
# 0      NaN                2           NaN               1               3
# 1      NaN                2           NaN               1               3
# 2      NaN                2           NaN               2               3
# 3      NaN                2           NaN               1               3
# 4      NaN                2           NaN               1               3
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate Region
# 0  1985-08-27       NaN     NaN       NaN      NaN      4
# 1  1985-08-27       NaN     NaN       NaN      NaN      4
# 2  1985-08-27       NaN     NaN       NaN      NaN      4
# 3  1985-08-27       NaN     NaN       NaN      NaN      4
# 4  1985-08-27       NaN     NaN       NaN      NaN      4

# %%
# replace values in Incompatibility column
incompatibility = {1:'Territory', 2:'Government', 3:'Government and Territory'}
dropped['Incompatibility'] = dropped['Incompatibility'].replace(incompatibility)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  IntensityLevel  TypeOfConflict  \
# 0      NaN      Government           NaN               1               3
# 1      NaN      Government           NaN               1               3
# 2      NaN      Government           NaN               2               3
# 3      NaN      Government           NaN               1               3
# 4      NaN      Government           NaN               1               3
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate Region
# 0  1985-08-27       NaN     NaN       NaN      NaN      4
# 1  1985-08-27       NaN     NaN       NaN      NaN      4
# 2  1985-08-27       NaN     NaN       NaN      NaN      4
# 3  1985-08-27       NaN     NaN       NaN      NaN      4
# 4  1985-08-27       NaN     NaN       NaN      NaN      4

# %%
# replace values in IntensityLevel column
intensity = {1:'Minor (between 25 and 999 battle-related deaths)', 2:'War (at least 1000 battle-related deaths)'}
dropped['IntensityLevel'] = dropped['IntensityLevel'].replace(intensity)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  \
# 0      NaN      Government           NaN
# 1      NaN      Government           NaN
# 2      NaN      Government           NaN
# 3      NaN      Government           NaN
# 4      NaN      Government           NaN
#
#                                      IntensityLevel  TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)               3
# 1  Minor (between 25 and 999 battle-related deaths)               3
# 2         War (at least 1000 battle-related deaths)               3
# 3  Minor (between 25 and 999 battle-related deaths)               3
# 4  Minor (between 25 and 999 battle-related deaths)               3
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate Region
# 0  1985-08-27       NaN     NaN       NaN      NaN      4
# 1  1985-08-27       NaN     NaN       NaN      NaN      4
# 2  1985-08-27       NaN     NaN       NaN      NaN      4
# 3  1985-08-27       NaN     NaN       NaN      NaN      4
# 4  1985-08-27       NaN     NaN       NaN      NaN      4

# %%
# replace values in TypeOfConflict column
conflict = {1:'Extrasystemic armed conflict', 2:'Interstate armed conflict', 3:'Internal armed conflict',
             4:'Internationalized internal armed'}
dropped['TypeOfConflict'] = dropped['TypeOfConflict'].replace(conflict)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  \
# 0      NaN      Government           NaN
# 1      NaN      Government           NaN
# 2      NaN      Government           NaN
# 3      NaN      Government           NaN
# 4      NaN      Government           NaN
#
#                                      IntensityLevel           TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 1  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 2         War (at least 1000 battle-related deaths)  Internal armed conflict
# 3  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 4  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate Region
# 0  1985-08-27       NaN     NaN       NaN      NaN      4
# 1  1985-08-27       NaN     NaN       NaN      NaN      4
# 2  1985-08-27       NaN     NaN       NaN      NaN      4
# 3  1985-08-27       NaN     NaN       NaN      NaN      4
# 4  1985-08-27       NaN     NaN       NaN      NaN      4

# %%
# replace values in Outcome column
outcome = {'1':'Peace agreement', '2':'Ceasefire', '3':'Victory for Side A /Government Side',
           '4':'Victory for Side B /Rebel Side', '5':'Low activity (less than 25 battle-deaths)', 
           '6':'Actor ceases to exist', '.':np.nan}
dropped['Outcome'] = dropped['Outcome'].replace(outcome)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  \
# 0      NaN      Government           NaN
# 1      NaN      Government           NaN
# 2      NaN      Government           NaN
# 3      NaN      Government           NaN
# 4      NaN      Government           NaN
#
#                                      IntensityLevel           TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 1  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 2         War (at least 1000 battle-related deaths)  Internal armed conflict
# 3  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 4  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate Region
# 0  1985-08-27       NaN     NaN       NaN      NaN      4
# 1  1985-08-27       NaN     NaN       NaN      NaN      4
# 2  1985-08-27       NaN     NaN       NaN      NaN      4
# 3  1985-08-27       NaN     NaN       NaN      NaN      4
# 4  1985-08-27       NaN     NaN       NaN      NaN      4

# %%
# # replace values in Region column
dropped['Region'] = dropped['Region'].str.replace('1', 'Europe')
dropped['Region'] = dropped['Region'].str.replace('2', 'Middle East')
dropped['Region'] = dropped['Region'].str.replace('3', 'Asia')
dropped['Region'] = dropped['Region'].str.replace('4', 'Africa')
dropped['Region'] = dropped['Region'].str.replace('5', 'Americas')
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  \
# 0      NaN      Government           NaN
# 1      NaN      Government           NaN
# 2      NaN      Government           NaN
# 3      NaN      Government           NaN
# 4      NaN      Government           NaN
#
#                                      IntensityLevel           TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 1  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 2         War (at least 1000 battle-related deaths)  Internal armed conflict
# 3  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 4  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate  Region
# 0  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 1  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 2  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 3  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 4  1985-08-27       NaN     NaN       NaN      NaN  Africa

# %%
# replace periods with NaN
period = {'.':np.nan}
dropped = dropped.replace(period)
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA2nd SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria      NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria      NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria      NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria      NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria      NaN   AIS
#
#   SideB2nd Incompatibility TerritoryName  \
# 0      NaN      Government           NaN
# 1      NaN      Government           NaN
# 2      NaN      Government           NaN
# 3      NaN      Government           NaN
# 4      NaN      Government           NaN
#
#                                      IntensityLevel           TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 1  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 2         War (at least 1000 battle-related deaths)  Internal armed conflict
# 3  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 4  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
#
#     StartDate EpEndDate Outcome CfireDate PeAgDate  Region
# 0  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 1  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 2  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 3  1985-08-27       NaN     NaN       NaN      NaN  Africa
# 4  1985-08-27       NaN     NaN       NaN      NaN  Africa

# %%
# rename some columns
dropped = dropped.rename({'SideA2nd':'SideA_Ally', 'SideB2nd':'SideB_Ally', 'EpEndDate':'EndDate', 
                'CfireDate':'CeasefireDate', 'PeAgDate':'PeaceAgreementDate', 'Incompatibility':'DisagreementOver'
                         }, axis=1)

# %%
dropped.head()
# Out:
#   ConflictId  DyadId  Year Location                  SideA SideA_Ally SideB  \
# 0      1-191       1  1992  Algeria  Government of Algeria        NaN   AIS
# 1      1-191       1  1993  Algeria  Government of Algeria        NaN   AIS
# 2      1-191       1  1994  Algeria  Government of Algeria        NaN   AIS
# 3      1-191       1  1995  Algeria  Government of Algeria        NaN   AIS
# 4      1-191       1  1996  Algeria  Government of Algeria        NaN   AIS
#
#   SideB_Ally DisagreementOver TerritoryName  \
# 0        NaN       Government           NaN
# 1        NaN       Government           NaN
# 2        NaN       Government           NaN
# 3        NaN       Government           NaN
# 4        NaN       Government           NaN
#
#                                      IntensityLevel           TypeOfConflict  \
# 0  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 1  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 2         War (at least 1000 battle-related deaths)  Internal armed conflict
# 3  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
# 4  Minor (between 25 and 999 battle-related deaths)  Internal armed conflict
#
#     StartDate EndDate Outcome CeasefireDate PeaceAgreementDate  Region
# 0  1985-08-27     NaN     NaN           NaN                NaN  Africa
# 1  1985-08-27     NaN     NaN           NaN                NaN  Africa
# 2  1985-08-27     NaN     NaN           NaN                NaN  Africa
# 3  1985-08-27     NaN     NaN           NaN                NaN  Africa
# 4  1985-08-27     NaN     NaN           NaN                NaN  Africa

# %%
dropped[(~dropped["Location"].str.contains(",")) & (dropped["TypeOfConflict"].str.contains('Internal armed conflict'))]
# Out:
#      ConflictId  DyadId  Year                  Location  \
# 0         1-191       1  1992                   Algeria
# 1         1-191       1  1993                   Algeria
# 2         1-191       1  1994                   Algeria
# 3         1-191       1  1995                   Algeria
# 4         1-191       1  1996                   Algeria
# 5         1-191       1  1997                   Algeria
# 6         1-191       2  1991                   Algeria
# 7         1-191       3  1993                   Algeria
# 8         1-191       3  1994                   Algeria
# 9         1-191       3  1995                   Algeria
# 10        1-191       3  1996                   Algeria
# 11        1-191       3  1997                   Algeria
# 12        1-191       3  1998                   Algeria
# 13        1-191       3  1999                   Algeria
# 14        1-191       3  2000                   Algeria
# 15        1-191       3  2001                   Algeria
# 16        1-191       3  2002                   Algeria
# 17        1-191       3  2003                   Algeria
# 18        1-191       4  1999                   Algeria
# 19        1-191       4  2000                   Algeria
# 20        1-191       4  2001                   Algeria
# 21        1-191       4  2002                   Algeria
# 22        1-191       4  2003                   Algeria
# 24        1-191       4  2005                   Algeria
# 25        1-191       4  2006                   Algeria
# 26        1-191       4  2007                   Algeria
# 27        1-191       4  2008                   Algeria
# 28        1-191       4  2009                   Algeria
# 29        1-191       4  2010                   Algeria
# 30        1-191       4  2011                   Algeria
# ...         ...     ...   ...                       ...
# 2702       1-68     856  2014          DR Congo (Zaire)
# 2703       1-86     858  2013          DR Congo (Zaire)
# 2704       1-86     858  2014          DR Congo (Zaire)
# 2705      1-270     859  2013               South Sudan
# 2707      1-270     860  2013               South Sudan
# 2708      1-278     861  2013                  Malaysia
# 2710      1-274     863  2009                      Mali
# 2714      1-102     867  2011                     Syria
# 2715      1-102     867  2012                     Syria
# 2716      1-102     867  2013                     Syria
# 2717      1-102     867  2014                     Syria
# 2718       1-33   10855  2014       Yemen (North Yemen)
# 2719      1-209   10961  2014                  Pakistan
# 2720      1-139   11299  2004                     India
# 2721       1-86   11377  2014          DR Congo (Zaire)
# 2722       1-29   11932  2000                     India
# 2723      1-222   12380  2013  Central African Republic
# 2724       1-86   12463  2013          DR Congo (Zaire)
# 2725      1-196   12487  2014                     Egypt
# 2727      1-271   14059  2014                     Libya
# 2728      1-280   14085  2014                   Ukraine
# 2729      1-227   14102  2013                     India
# 2730      1-227   14102  2014                     India
# 2732      1-113   14134  2014                     Sudan
# 2733      1-113   14150  2014                     Sudan
# 2736      1-209   14227  2014                  Pakistan
# 2737       1-63   14244  2014                   Lebanon
# 2738      1-271   14249  2014                     Libya
# 2739      1-279   14273  2013           Myanmar (Burma)
# 2740      1-279   14273  2014           Myanmar (Burma)
#
#                                        SideA SideA_Ally  \
# 0                      Government of Algeria        NaN
# 1                      Government of Algeria        NaN
# 2                      Government of Algeria        NaN
# 3                      Government of Algeria        NaN
# 4                      Government of Algeria        NaN
# 5                      Government of Algeria        NaN
# 6                      Government of Algeria        NaN
# 7                      Government of Algeria        NaN
# 8                      Government of Algeria        NaN
# 9                      Government of Algeria        NaN
# 10                     Government of Algeria        NaN
# 11                     Government of Algeria        NaN
# 12                     Government of Algeria        NaN
# 13                     Government of Algeria        NaN
# 14                     Government of Algeria        NaN
# 15                     Government of Algeria        NaN
# 16                     Government of Algeria        NaN
# 17                     Government of Algeria        NaN
# 18                     Government of Algeria        NaN
# 19                     Government of Algeria        NaN
# 20                     Government of Algeria        NaN
# 21                     Government of Algeria        NaN
# 22                     Government of Algeria        NaN
# 24                     Government of Algeria        NaN
# 25                     Government of Algeria        NaN
# 26                     Government of Algeria        NaN
# 27                     Government of Algeria        NaN
# 28                     Government of Algeria        NaN
# 29                     Government of Algeria        NaN
# 30                     Government of Algeria        NaN
# ...                                      ...        ...
# 2702         Government of DR Congo (Zaire)         NaN
# 2703         Government of DR Congo (Zaire)         NaN
# 2704         Government of DR Congo (Zaire)         NaN
# 2705               Government of South Sudan        NaN
# 2707               Government of South Sudan        NaN
# 2708                  Government of Malaysia        NaN
# 2710                      Government of Mali        NaN
# 2714                     Government of Syria        NaN
# 2715                     Government of Syria        NaN
# 2716                     Government of Syria        NaN
# 2717                     Government of Syria        NaN
# 2718       Government of Yemen (North Yemen)        NaN
# 2719                  Government of Pakistan        NaN
# 2720                     Government of India        NaN
# 2721         Government of DR Congo (Zaire)         NaN
# 2722                     Government of India        NaN
# 2723  Government of Central African Republic        NaN
# 2724         Government of DR Congo (Zaire)         NaN
# 2725                     Government of Egypt        NaN
# 2727                     Government of Libya        NaN
# 2728                   Government of Ukraine        NaN
# 2729                     Government of India        NaN
# 2730                     Government of India        NaN
# 2732                     Government of Sudan        NaN
# 2733                     Government of Sudan        NaN
# 2736                  Government of Pakistan        NaN
# 2737                   Government of Lebanon        NaN
# 2738                     Government of Libya        NaN
# 2739           Government of Myanmar (Burma)        NaN
# 2740           Government of Myanmar (Burma)        NaN
#
#                                   SideB SideB_Ally DisagreementOver  \
# 0                                   AIS        NaN       Government
# 1                                   AIS        NaN       Government
# 2                                   AIS        NaN       Government
# 3                                   AIS        NaN       Government
# 4                                   AIS        NaN       Government
# 5                                   AIS        NaN       Government
# 6                     Takfir wa'l Hijra        NaN       Government
# 7                                   GIA        NaN       Government
# 8                                   GIA        NaN       Government
# 9                                   GIA        NaN       Government
# 10                                  GIA        NaN       Government
# 11                                  GIA        NaN       Government
# 12                                  GIA        NaN       Government
# 13                                  GIA        NaN       Government
# 14                                  GIA        NaN       Government
# 15                                  GIA        NaN       Government
# 16                                  GIA        NaN       Government
# 17                                  GIA        NaN       Government
# 18                                 AQIM        NaN       Government
# 19                                 AQIM        NaN       Government
# 20                                 AQIM        NaN       Government
# 21                                 AQIM        NaN       Government
# 22                                 AQIM        NaN       Government
# 24                                 AQIM        NaN       Government
# 25                                 AQIM        NaN       Government
# 26                                 AQIM        NaN       Government
# 27                                 AQIM        NaN       Government
# 28                                 AQIM        NaN       Government
# 29                                 AQIM        NaN       Government
# 30                                 AQIM        NaN       Government
# ...                                 ...        ...              ...
# 2702                       Kata Katanga        NaN        Territory
# 2703                              APCLS        NaN       Government
# 2704                              APCLS        NaN       Government
# 2705               SPLM/A In Opposition        NaN       Government
# 2707             SSDM/A - Cobra Faction        NaN       Government
# 2708                  Sultanate of Sulu        NaN        Territory
# 2710                               AQIM        NaN       Government
# 2714                  Syrian insurgents        NaN       Government
# 2715                  Syrian insurgents        NaN       Government
# 2716                  Syrian insurgents        NaN       Government
# 2717                  Syrian insurgents        NaN       Government
# 2718                         Ansarallah        NaN       Government
# 2719                                IMU        NaN       Government
# 2720                             NLFT-B        NaN        Territory
# 2721                          PARC-FAAL        NaN       Government
# 2722                           CPI-ML-J        NaN       Government
# 2723                        anti-Balaka        NaN       Government
# 2724  Forces of Paul Joseph Mukungubila        NaN       Government
# 2725                              IS-SP        NaN       Government
# 2727               Libyan National Army        NaN       Government
# 2728                             Maidan        NaN       Government
# 2729                             NDFB-S        NaN        Territory
# 2730                             NDFB-S        NaN        Territory
# 2732                               SARC        NaN       Government
# 2733     Darfur Joint Resistance Forces        NaN       Government
# 2736                    Jamaat-ul-Ahrar        NaN       Government
# 2737                                 IS        NaN       Government
# 2738                    Zintan Brigades        NaN       Government
# 2739                               PSLF        NaN        Territory
# 2740                               PSLF        NaN        Territory
#
#      TerritoryName                                    IntensityLevel  \
# 0              NaN  Minor (between 25 and 999 battle-related deaths)
# 1              NaN  Minor (between 25 and 999 battle-related deaths)
# 2              NaN         War (at least 1000 battle-related deaths)
# 3              NaN  Minor (between 25 and 999 battle-related deaths)
# 4              NaN  Minor (between 25 and 999 battle-related deaths)
# 5              NaN  Minor (between 25 and 999 battle-related deaths)
# 6              NaN  Minor (between 25 and 999 battle-related deaths)
# 7              NaN  Minor (between 25 and 999 battle-related deaths)
# 8              NaN  Minor (between 25 and 999 battle-related deaths)
# 9              NaN         War (at least 1000 battle-related deaths)
# 10             NaN         War (at least 1000 battle-related deaths)
# 11             NaN         War (at least 1000 battle-related deaths)
# 12             NaN         War (at least 1000 battle-related deaths)
# 13             NaN  Minor (between 25 and 999 battle-related deaths)
# 14             NaN  Minor (between 25 and 999 battle-related deaths)
# 15             NaN  Minor (between 25 and 999 battle-related deaths)
# 16             NaN  Minor (between 25 and 999 battle-related deaths)
# 17             NaN  Minor (between 25 and 999 battle-related deaths)
# 18             NaN  Minor (between 25 and 999 battle-related deaths)
# 19             NaN  Minor (between 25 and 999 battle-related deaths)
# 20             NaN  Minor (between 25 and 999 battle-related deaths)
# 21             NaN  Minor (between 25 and 999 battle-related deaths)
# 22             NaN  Minor (between 25 and 999 battle-related deaths)
# 24             NaN  Minor (between 25 and 999 battle-related deaths)
# 25             NaN  Minor (between 25 and 999 battle-related deaths)
# 26             NaN  Minor (between 25 and 999 battle-related deaths)
# 27             NaN  Minor (between 25 and 999 battle-related deaths)
# 28             NaN  Minor (between 25 and 999 battle-related deaths)
# 29             NaN  Minor (between 25 and 999 battle-related deaths)
# 30             NaN  Minor (between 25 and 999 battle-related deaths)
# ...            ...                                               ...
# 2702       Katanga  Minor (between 25 and 999 battle-related deaths)
# 2703           NaN  Minor (between 25 and 999 battle-related deaths)
# 2704           NaN  Minor (between 25 and 999 battle-related deaths)
# 2705           NaN  Minor (between 25 and 999 battle-related deaths)
# 2707           NaN  Minor (between 25 and 999 battle-related deaths)
# 2708         Sabah  Minor (between 25 and 999 battle-related deaths)
# 2710           NaN  Minor (between 25 and 999 battle-related deaths)
# 2714           NaN  Minor (between 25 and 999 battle-related deaths)
# 2715           NaN         War (at least 1000 battle-related deaths)
# 2716           NaN         War (at least 1000 battle-related deaths)
# 2717           NaN         War (at least 1000 battle-related deaths)
# 2718           NaN  Minor (between 25 and 999 battle-related deaths)
# 2719           NaN  Minor (between 25 and 999 battle-related deaths)
# 2720       Tripura  Minor (between 25 and 999 battle-related deaths)
# 2721           NaN  Minor (between 25 and 999 battle-related deaths)
# 2722           NaN  Minor (between 25 and 999 battle-related deaths)
# 2723           NaN  Minor (between 25 and 999 battle-related deaths)
# 2724           NaN  Minor (between 25 and 999 battle-related deaths)
# 2725           NaN  Minor (between 25 and 999 battle-related deaths)
# 2727           NaN  Minor (between 25 and 999 battle-related deaths)
# 2728           NaN  Minor (between 25 and 999 battle-related deaths)
# 2729      Bodoland  Minor (between 25 and 999 battle-related deaths)
# 2730      Bodoland  Minor (between 25 and 999 battle-related deaths)
# 2732           NaN  Minor (between 25 and 999 battle-related deaths)
# 2733           NaN  Minor (between 25 and 999 battle-related deaths)
# 2736           NaN  Minor (between 25 and 999 battle-related deaths)
# 2737           NaN  Minor (between 25 and 999 battle-related deaths)
# 2738           NaN  Minor (between 25 and 999 battle-related deaths)
# 2739       Palaung  Minor (between 25 and 999 battle-related deaths)
# 2740       Palaung  Minor (between 25 and 999 battle-related deaths)
#
#                TypeOfConflict   StartDate     EndDate  \
# 0     Internal armed conflict  1985-08-27         NaN
# 1     Internal armed conflict  1985-08-27         NaN
# 2     Internal armed conflict  1985-08-27         NaN
# 3     Internal armed conflict  1985-08-27         NaN
# 4     Internal armed conflict  1985-08-27         NaN
# 5     Internal armed conflict  1985-08-27     10/1/97
# 6     Internal armed conflict  1990-12-20    12/31/91
# 7     Internal armed conflict  1992-02-10         NaN
# 8     Internal armed conflict  1992-02-10         NaN
# 9     Internal armed conflict  1992-02-10         NaN
# 10    Internal armed conflict  1992-02-10         NaN
# 11    Internal armed conflict  1992-02-10         NaN
# 12    Internal armed conflict  1992-02-10         NaN
# 13    Internal armed conflict  1992-02-10         NaN
# 14    Internal armed conflict  1992-02-10         NaN
# 15    Internal armed conflict  1992-02-10         NaN
# 16    Internal armed conflict  1992-02-10         NaN
# 17    Internal armed conflict  1992-02-10    12/31/03
# 18    Internal armed conflict  1998-12-15         NaN
# 19    Internal armed conflict  1998-12-15         NaN
# 20    Internal armed conflict  1998-12-15         NaN
# 21    Internal armed conflict  1998-12-15         NaN
# 22    Internal armed conflict  1998-12-15         NaN
# 24    Internal armed conflict  1998-12-15         NaN
# 25    Internal armed conflict  1998-12-15         NaN
# 26    Internal armed conflict  1998-12-15         NaN
# 27    Internal armed conflict  1998-12-15         NaN
# 28    Internal armed conflict  1998-12-15         NaN
# 29    Internal armed conflict  1998-12-15         NaN
# 30    Internal armed conflict  1998-12-15         NaN
# ...                       ...         ...         ...
# 2702  Internal armed conflict  2011-12-04         NaN
# 2703  Internal armed conflict  2012-10-06         NaN
# 2704  Internal armed conflict  2012-10-06         NaN
# 2705  Internal armed conflict  2013-12-15         NaN
# 2707  Internal armed conflict  2011-09-26    12/31/13
# 2708  Internal armed conflict  2013-03-01     3/24/13
# 2710  Internal armed conflict  2009-06-14  2009-07-16
# 2714  Internal armed conflict  2011-09-19         NaN
# 2715  Internal armed conflict  2011-09-19         NaN
# 2716  Internal armed conflict  2011-09-19         NaN
# 2717  Internal armed conflict  2011-09-19         NaN
# 2718  Internal armed conflict  2014-03-13         NaN
# 2719  Internal armed conflict  2009-08-27         NaN
# 2720  Internal armed conflict  2003-11-22  2004-12-28
# 2721  Internal armed conflict  2012-02-08         NaN
# 2722  Internal armed conflict  1999-03-08    12/31/00
# 2723  Internal armed conflict  2013-04-14    12/31/13
# 2724  Internal armed conflict  2013-12-30    12/31/13
# 2725  Internal armed conflict  2014-03-11         NaN
# 2727  Internal armed conflict  2014-12-02         NaN
# 2728  Internal armed conflict  2014-01-22         NaN
# 2729  Internal armed conflict  2013-01-14         NaN
# 2730  Internal armed conflict  2013-01-14         NaN
# 2732  Internal armed conflict  2014-02-28         NaN
# 2733  Internal armed conflict  2014-03-02         NaN
# 2736  Internal armed conflict  2014-03-03         NaN
# 2737  Internal armed conflict  2014-06-25         NaN
# 2738  Internal armed conflict  2014-05-18         NaN
# 2739  Internal armed conflict  2013-03-22         NaN
# 2740  Internal armed conflict  2013-03-22         NaN
#
#                                         Outcome CeasefireDate  \
# 0                                           NaN           NaN
# 1                                           NaN           NaN
# 2                                           NaN           NaN
# 3                                           NaN           NaN
# 4                                           NaN           NaN
# 5                                     Ceasefire       10/1/97
# 6                         Actor ceases to exist           NaN
# 7                                           NaN           NaN
# 8                                           NaN           NaN
# 9                                           NaN           NaN
# 10                                          NaN           NaN
# 11                                          NaN           NaN
# 12                                          NaN           NaN
# 13                                          NaN           NaN
# 14                                          NaN           NaN
# 15                                          NaN           NaN
# 16                                          NaN           NaN
# 17    Low activity (less than 25 battle-deaths)           NaN
# 18                                          NaN           NaN
# 19                                          NaN           NaN
# 20                                          NaN           NaN
# 21                                          NaN           NaN
# 22                                          NaN           NaN
# 24                                          NaN           NaN
# 25                                          NaN           NaN
# 26                                          NaN           NaN
# 27                                          NaN           NaN
# 28                                          NaN           NaN
# 29                                          NaN           NaN
# 30                                          NaN           NaN
# ...                                         ...           ...
# 2702                                        NaN           NaN
# 2703                                        NaN           NaN
# 2704                                        NaN           NaN
# 2705                                        NaN           NaN
# 2707                            Peace agreement        1/7/14
# 2708        Victory for Side A /Government Side           NaN
# 2710  Low activity (less than 25 battle-deaths)           NaN
# 2714                                        NaN           NaN
# 2715                                        NaN           NaN
# 2716                                        NaN           NaN
# 2717                                        NaN           NaN
# 2718                                        NaN           NaN
# 2719                                        NaN           NaN
# 2720  Low activity (less than 25 battle-deaths)           NaN
# 2721                                        NaN           NaN
# 2722  Low activity (less than 25 battle-deaths)           NaN
# 2723  Low activity (less than 25 battle-deaths)           NaN
# 2724        Victory for Side A /Government Side           NaN
# 2725                                        NaN           NaN
# 2727                                        NaN           NaN
# 2728                                        NaN           NaN
# 2729                                        NaN           NaN
# 2730                                        NaN           NaN
# 2732                                        NaN           NaN
# 2733                                        NaN           NaN
# 2736                                        NaN           NaN
# 2737                                        NaN           NaN
# 2738                                        NaN           NaN
# 2739                                        NaN           NaN
# 2740                                        NaN           NaN
#
#      PeaceAgreementDate       Region
# 0                   NaN       Africa
# 1                   NaN       Africa
# 2                   NaN       Africa
# 3                   NaN       Africa
# 4                   NaN       Africa
# 5                   NaN       Africa
# 6                   NaN       Africa
# 7                   NaN       Africa
# 8                   NaN       Africa
# 9                   NaN       Africa
# 10                  NaN       Africa
# 11                  NaN       Africa
# 12                  NaN       Africa
# 13                  NaN       Africa
# 14                  NaN       Africa
# 15                  NaN       Africa
# 16                  NaN       Africa
# 17                  NaN       Africa
# 18                  NaN       Africa
# 19                  NaN       Africa
# 20                  NaN       Africa
# 21                  NaN       Africa
# 22                  NaN       Africa
# 24                  NaN       Africa
# 25                  NaN       Africa
# 26                  NaN       Africa
# 27                  NaN       Africa
# 28                  NaN       Africa
# 29                  NaN       Africa
# 30                  NaN       Africa
# ...                 ...          ...
# 2702                NaN       Africa
# 2703                NaN       Africa
# 2704                NaN       Africa
# 2705                NaN       Africa
# 2707             5/9/14       Africa
# 2708                NaN         Asia
# 2710                NaN       Africa
# 2714                NaN  Middle East
# 2715                NaN  Middle East
# 2716                NaN  Middle East
# 2717                NaN  Middle East
# 2718                NaN  Middle East
# 2719                NaN         Asia
# 2720                NaN         Asia
# 2721                NaN       Africa
# 2722                NaN         Asia
# 2723                NaN       Africa
# 2724                NaN       Africa
# 2725                NaN  Middle East
# 2727                NaN       Africa
# 2728                NaN       Europe
# 2729                NaN         Asia
# 2730                NaN         Asia
# 2732                NaN       Africa
# 2733                NaN       Africa
# 2736                NaN         Asia
# 2737                NaN  Middle East
# 2738                NaN       Africa
# 2739                NaN         Asia
# 2740                NaN         Asia
#
# [2090 rows x 18 columns]

# %%
dropped.set_index('Year').to_csv('cleanedWars2.csv')

# %% [markdown]
# ### Edits to dataset after meeting with professor

# %%
# Drop remaining columns that are not needed after meeting with professor
dropped = dropped.drop(['Year', 'SideA_Ally', 'SideB_Ally', 'TerritoryName', 'CeasefireDate', 
                        'PeaceAgreementDate'], axis = 1)
dropped.head()

# %%
# Taking out locations with commas ","", i.e. interstate wars
dropped = dropped[~dropped["Location"].str.contains(",")]
dropped[dropped["Location"].str.contains(",")]

# %%
# Dropping remaining interstate conflicts
dropped = dropped[dropped["TypeOfConflict"].str.contains('Internal armed conflict')]
dropped.head()

# %%
# replace NaN values with "Missing" string
dropped = dropped.fillna('Missing')
dropped.head()

# %%
# Extracting start years of wars from start dates
dropped['StartDate'] = pd.to_datetime(dropped['StartDate'])
dropped['StartYear'] = dropped['StartDate'].dt.year
dropped.head()

# %%
# Extracting end years of wars from end dates

# replace missing end dates with NaT so can convert to datetime and extract year
dropped['EndYear'] = dropped['EndDate']
dropped['EndYear'] = dropped['EndYear'].replace('Missing','NaT')

dropped['EndYear'] = pd.to_datetime(dropped['EndYear'])
dropped['EndYear'] = dropped['EndYear'].dt.year
dropped = dropped.fillna('Missing')

dropped.head(10)

# %%
# One approach of getting one row per conflict, but 
# some conflicts still have more than one row since more than one end date was listed

conflict_rows = dropped[dropped['EndDate'] != 'Missing']
conflict_rows.head()

# %% [markdown]
# ### The code below produces the final dataframe that is currently used in the Civil Wars notebook

# %%
#  Another approach for getting one row per conflict where there is one row per conflict 

#Replace missing with NaN again so that can use function in apply
one = dropped.replace('Missing', np.nan)

# One row per conflict grouped by ConflictId and DyadId
one.groupby(['ConflictId', 'DyadId'], sort = False)['EndYear'].apply(np.nanmax)
idx = one.groupby(['ConflictId', 'DyadId'])['EndYear'].transform(max) == one['EndYear']


one_row = one[idx]
one_row.head()

# %%
# Reformatting values including start and end date formats 

one_row.fillna('Missing')
one_row['StartDate'] = one_row['StartDate'].dt.strftime('%m/%d/%Y')
one_row['EndDate'] = pd.to_datetime(one_row['EndDate'])
one_row['EndDate'] = one_row['EndDate'].dt.strftime('%m/%d/%Y')

one_row.head()

# %%
# Dropping StartYear and EndYear columns

one_row.drop(['StartYear', 'EndYear'], axis = 1, inplace = True)
one_row.head()

# %%
one_row[one_row["IntensityLevel"].str.contains("War")]

# %%
approach_1 = conflict_rows.shape[0]
approach_2 = one_row.shape[0]

print('Approach 1 number of rows: ', approach_1)
print('Approach 2 number of rows:', approach_2)

# %%
one_row.set_index('ConflictId').to_csv('oneWar.csv')
